# %%
import pickle
traindata=[]
testdata=[]
with open('traindata.txt', 'rb') as filehandle:
    # read the data as binary data stream
    traindata = pickle.load(filehandle)

# %%
with open('testdata.txt', 'rb') as filehandle:
    # read the data as binary data stream
    testdata= pickle.load(filehandle)

# %%
import numpy as np
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
from random import seed
from random import random

seed(1)

# %%
data,lab=zip(*traindata)

# %%
w=[] 
for i in range(1500):
    w.append(random())

# %%
def predict(w,dict):
    i=0 
    sum=0 
    for a,b in dict.items():
        if b:
            sum=sum+w[i]
        i=i+1 
        
    prob=sigmoid(sum)
    return prob

# %%
###Using Batch Gradient Descent
n=1500 
alpha=100
for iteration in range(100):
    delw=np.zeros(n)
    m=len(data)
    for i in range(m):
        prediction=predict(w,data[i])
        
        j=0 ;
        
        for a,b in data[i].items():
            if b :
                delw[j]=delw[j]+(prediction-lab[i])
            
            j=j+1 
            
    
    for i in range(n):
        delw[i]=delw[i]/m 
       
    for i in range(n):
        w[i]=w[i]-alpha*delw[i]

# %%
print(w)
predictions=[] 
testd,label=data,lab
# Out:
# [-2.468949022851447, 0.6487836110886407, -3.1840339128060537, -1.9588849446139305, -1.1189915020239383, -4.459385049898677, -4.178500883960535, -1.7320084436969976, -0.3609175399859532, 1.020421412489827, -3.595097848959312, -3.1082555548940607, -1.5667135053662393, -2.2864405386803472, -2.9751323119612088, -0.8318089725495317, -2.731457898525017, -0.6884327830389296, 1.4677685054574157, -0.43210073595371296, 3.491744384609587, -2.2563555011080974, -2.4125917043663225, -1.6137316581865198, -1.1949677473884457, -2.0064353146365965, 0.9404961270778691, 3.3142218965153774, -3.6996342649686658, -1.9170498033070003, 2.666198088028762, 0.17350983583949278, -3.3261484146029856, -2.200464045825936, -4.184638543651162, -2.165139170885618, -2.0257230906725696, -1.6836710519605573, 3.557724387558493, -0.7181961374895092, -2.7580731359017827, -1.0407297386941792, -1.3722885831351856, -0.9415887538179776, -0.22822756806875483, -0.6528787786286021, -2.176578441363679, -0.4648258435037177, -2.181318354962453, 1.6265750169624673, -2.069551337452132, -3.668799027069845, -0.7354773363633547, -2.2864564894861523, -2.2142032421997584, 0.5261056572888195, 1.607043391045572, -2.3780719268724204, 1.833366085712445, -0.6258092205025759, -0.8348839138514319, -2.8077899123056103, 1.149545855208345, -0.7401977590277028, -2.923098234087456, -2.945389325487613, -1.1587087027360292, -0.8088546237208499, -2.01884403720736, -1.922785697165104, -3.546528710818334, 3.7189222384309812, -2.9680442686902118, -2.246979154005157, -2.23503136051039, -0.7021853283809186, -1.322459580006114, -1.110666925886